# %%
import pandas as pd
#creating the dataframes / importing the data
employees = pd.read_excel("../data_raw/Total_employees.xlsx")
unemployees = pd.read_excel("../data_raw/Unemployees.xlsx")
openings = pd.read_excel("../data_raw/Job_openings.xlsx")
layoffs = pd.read_excel("../data_raw/Layoff_rates.xlsx")
hires = pd.read_excel("../data_raw/Hire_rate.xlsx")
# Out:
# C:\Users\diego\Documents\Unemployment_2016-2026\env\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\diego\Documents\Unemployment_2016-2026\env\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\diego\Documents\Unemployment_2016-2026\env\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\diego\Documents\Unemployment_2016-2026\env\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
#since it has a description I'm verifying by 15 rows if the data appears therefore it's reading it correctly
employees.head(15)
openings.head(15)
layoffs.head(15)
hires.head(15)
unemployees.head(15)
# Out:
#    Labor Force Statistics from the Current Population Survey  \
# 0                                 Original Data Value
# 1                                                 NaN
# 2                                          Series Id:
# 3                                 Seasonally Adjusted
# 4                                       Series title:
# 5                                 Labor force status:
# 6                                       Type of data:
# 7                                                Age:
# 8                                              Years:
# 9                                                 NaN
# 10                                               Year
# 11                                               2016
# 12                                               2017
# 13                                               2018
# 14                                               2019
#
#                    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                         NaN        NaN        NaN        NaN        NaN
# 1                         NaN        NaN        NaN        NaN        NaN
# 2                 LNS13000000        NaN        NaN        NaN        NaN
# 3                         NaN        NaN        NaN        NaN        NaN
# 4   (Seas) Unemployment Level        NaN        NaN        NaN        NaN
# 5                  Unemployed        NaN        NaN        NaN        NaN
# 6         Number in thousands        NaN        NaN        NaN        NaN
# 7           16 years and over        NaN        NaN        NaN        NaN
# 8                2016 to 2026        NaN        NaN        NaN        NaN
# 9                         NaN        NaN        NaN        NaN        NaN
# 10                        Jan        Feb        Mar        Apr        May
# 11                       7627       7702       7961       8067       7652
# 12                       7468       7379       7073       7089       7000
# 13                       6489       6581       6472       6459       6196
# 14                       6475       6136       6202       5961       5930
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0         NaN        NaN        NaN        NaN         NaN         NaN
# 1         NaN        NaN        NaN        NaN         NaN         NaN
# 2         NaN        NaN        NaN        NaN         NaN         NaN
# 3         NaN        NaN        NaN        NaN         NaN         NaN
# 4         NaN        NaN        NaN        NaN         NaN         NaN
# 5         NaN        NaN        NaN        NaN         NaN         NaN
# 6         NaN        NaN        NaN        NaN         NaN         NaN
# 7         NaN        NaN        NaN        NaN         NaN         NaN
# 8         NaN        NaN        NaN        NaN         NaN         NaN
# 9         NaN        NaN        NaN        NaN         NaN         NaN
# 10        Jun        Jul        Aug        Sep         Oct         Nov
# 11       7744       7641       7784       7953        7811        7553
# 12       6873       6892       7082       6854        6700        6774
# 13       6447       6195       6156       6073        6211        6115
# 14       5935       6061       5945       5753        5871        5868
#
#    Unnamed: 12
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         Dec
# 11        7521
# 12        6632
# 13        6389
# 14        5853

# %%
unemployees.columns
# Out:
# Index(['Labor Force Statistics from the Current Population Survey',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12'],
#       dtype='str')

# %%
#this line is to delete the description of the data that appears on the excel file.
employees = employees.iloc[11:]
openings = openings.iloc[12:]
layoffs = layoffs.iloc[12:]
hires = hires.iloc[12:]
unemployees = unemployees.iloc[10:]

# %%
unemployees.head(15)
# Out:
#    Labor Force Statistics from the Current Population Survey Unnamed: 1  \
# 10                                               Year               Jan
# 11                                               2016              7627
# 12                                               2017              7468
# 13                                               2018              6489
# 14                                               2019              6475
# 15                                               2020              5869
# 16                                               2021             10260
# 17                                               2022              6533
# 18                                               2023              5770
# 19                                               2024              6175
# 20                                               2025              6865
# 21                                               2026              7368
#
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 10        Feb        Mar        Apr        May        Jun        Jul
# 11       7702       7961       8067       7652       7744       7641
# 12       7379       7073       7089       7000       6873       6892
# 13       6581       6472       6459       6196       6447       6195
# 14       6136       6202       5961       5930       5935       6061
# 15       5753       7206      23084      20929      17652      16352
# 16      10013       9772       9754       9260       9481       8731
# 17       6323       6033       5995       5979       5975       5770
# 18       5987       5859       5747       6084       5985       5923
# 19       6486       6521       6486       6627       6881       7098
# 20       7104       7132       7155       7248       7054       7272
# 21       7571       7239       7373       7307       7094       6916
#
#    Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 10        Aug        Sep         Oct         Nov         Dec
# 11       7784       7953        7811        7553        7521
# 12       7082       6854        6700        6774        6632
# 13       6156       6073        6211        6115        6389
# 14       5945       5753        5871        5868        5853
# 15      13461      12554       11072       10694       10770
# 16       8269       7610        7267        6729        6413
# 17       5909       5747        5949        5918        5781
# 18       6275       6274        6463        6226        6329
# 19       7063       6849        6951        7089        6920
# 20       7380       7605         NaN        7781        7503
# 21        NaN        NaN         NaN         NaN         NaN

# %%
#I'm resetting the index so it doesn't count the description rows that I deleted
employees = employees.reset_index(drop=True)
openings = openings.reset_index(drop=True)
layoffs = layoffs.reset_index(drop=True)
hires = hires.reset_index(drop=True)
unemployees = unemployees.reset_index(drop=True)

# %%
#This is to verify if it has all the columns, in total should be 13 (12 due to the months and the extra for the title)
layoffs.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 13 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Job Openings and Labor Turnover Survey  12 non-null     object
#  1   Unnamed: 1                              12 non-null     object
#  2   Unnamed: 2                              12 non-null     object
#  3   Unnamed: 3                              12 non-null     object
#  4   Unnamed: 4                              12 non-null     object
#  5   Unnamed: 5                              12 non-null     object
#  6   Unnamed: 6                              11 non-null     object
#  7   Unnamed: 7                              11 non-null     object
#  8   Unnamed: 8                              11 non-null     object
#  9   Unnamed: 9                              11 non-null     object
#  10  Unnamed: 10                             11 non-null     object
#  11  Unnamed: 11                             11 non-null     object
#  12  Unnamed: 12                             11 non-null     object
# dtypes: object(13)
# memory usage: 1.3+ KB

# %%
unemployees.head()
# Out:
#   Labor Force Statistics from the Current Population Survey Unnamed: 1  \
# 0                                               Year               Jan
# 1                                               2016              7627
# 2                                               2017              7468
# 3                                               2018              6489
# 4                                               2019              6475
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0        Feb        Mar        Apr        May        Jun        Jul
# 1       7702       7961       8067       7652       7744       7641
# 2       7379       7073       7089       7000       6873       6892
# 3       6581       6472       6459       6196       6447       6195
# 4       6136       6202       5961       5930       5935       6061
#
#   Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0        Aug        Sep         Oct         Nov         Dec
# 1       7784       7953        7811        7553        7521
# 2       7082       6854        6700        6774        6632
# 3       6156       6073        6211        6115        6389
# 4       5945       5753        5871        5868        5853

# %%
#This is to fix the error that the it was reading the wrong data and set it into the columns, so I redifined the right columns
employees.columns = employees.iloc[0]
employees = employees[1:].reset_index(drop=True)

openings.columns = openings.iloc[0]
openings = openings[1:].reset_index(drop=True)

layoffs.columns = layoffs.iloc[0]
layoffs = layoffs[1:].reset_index(drop=True)

hires.columns = hires.iloc[0]
hires = hires[1:].reset_index(drop=True)

unemployees.columns = unemployees.iloc[0]
unemployees = unemployees[1:].reset_index(drop=True)

# %%
employees.head()
# Out:
# 0  Year     Jan     Feb     Mar     Apr     May     Jun     Jul     Aug  \
# 0  2016  143210  143406  143662  143854  143900  144147  144520  144661
# 1  2017  145628  145846  145970  146175  146380  146583  146772  146919
# 2  2018  147660  148054  148280  148420  148742  148960  149020  149277
# 3  2019  150060  150067  150295  150591  150618  150838  150937  151169
# 4  2020  152031  152293  150895  130426  133040  137671  139255  140821
#
# 0     Sep     Oct     Nov     Dec
# 0  144967  145065  145183  145408
# 1  147008  147149  147372  147523
# 2  149358  149527  149617  149809
# 3  151365  151460  151667  151794
# 4  141770  142460  142733  142548

# %%
#this creates a new column with the average from january to december(all months), then it groups it by year.
employees["Employees_Avg"] = employees.loc[:, "Jan":"Dec"].mean(axis=1)
employees_avg = employees[["Year", "Employees_Avg"]]

openings["Openings_Avg"] = openings.loc[:, "Jan":"Dec"].mean(axis=1)
openings_avg = openings[["Year", "Openings_Avg"]]
#Hires is a rate- type value
hires["Hires_Avg"] = hires.loc[:, "Jan":"Dec"].mean(axis=1)
hires_avg = hires[["Year", "Hires_Avg"]]
#layoffs is a rate-type value
layoffs["Layoffs_Avg"] = layoffs.loc[:, "Jan":"Dec"].mean(axis=1)
layoffs_avg = layoffs[["Year", "Layoffs_Avg"]]

unemployees["Unemployees_Avg"] = unemployees.loc[:, "Jan":"Dec"].mean(axis=1)
unemployees_avg = unemployees[["Year", "Unemployees_Avg"]]

# %%
unemployees.head()
# Out:
# 0  Year   Jan   Feb   Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# 0  2016  7627  7702  7961   8067   7652   7744   7641   7784   7953   7811
# 1  2017  7468  7379  7073   7089   7000   6873   6892   7082   6854   6700
# 2  2018  6489  6581  6472   6459   6196   6447   6195   6156   6073   6211
# 3  2019  6475  6136  6202   5961   5930   5935   6061   5945   5753   5871
# 4  2020  5869  5753  7206  23084  20929  17652  16352  13461  12554  11072
#
# 0    Nov    Dec Unemployees_Avg
# 0   7553   7521     7751.333333
# 1   6774   6632     6984.666667
# 2   6115   6389         6315.25
# 3   5868   5853     5999.166667
# 4  10694  10770    12949.666667

# %%
#Now I merged properly grouping them by year. Also I set unemployees column next to employees for easier readability
merged = employees_avg.merge(unemployees_avg, on="Year") \
.merge(openings_avg, on="Year") \
.merge(hires_avg, on="Year") \
.merge(layoffs_avg, on="Year")

# %%
merged.head(15)
# Out:
# 0   Year  Employees_Avg Unemployees_Avg Openings_Avg Hires_Avg Layoffs_Avg
# 0   2016  144331.916667     7751.333333       5855.5  3.691667       1.225
# 1   2017  146610.416667     6984.666667       6118.5     3.725       1.225
# 2   2018  148893.666667         6315.25  7109.166667      3.85    1.216667
# 3   2019  150905.083333     5999.166667  7153.833333  3.866667    1.208333
# 4   2020  142161.916667    12949.666667  6349.333333  4.258333         2.4
# 5   2021  146284.333333     8629.916667  9979.416667  4.341667    0.966667
# 6   2022  152549.166667     5992.666667     11194.75       4.2    0.958333
# 7   2023      155895.25     6076.833333       9268.0  3.758333    1.066667
# 8   2024  157693.833333     6762.166667  7656.666667  3.416667    1.058333
# 9   2025  158438.916667     7281.727273  7081.666667  3.316667    1.116667
# 10  2026  158731.166667     7266.857143       7245.6      3.32        1.08

# %%
#Converting them into real counts 
merged[["Employees_Avg","Unemployees_Avg","Openings_Avg"]] *=1000
merged.head(15)
# Out:
# 0   Year     Employees_Avg  Unemployees_Avg    Openings_Avg Hires_Avg  \
# 0   2016  144331916.666667   7751333.333333       5855500.0  3.691667
# 1   2017  146610416.666667   6984666.666667       6118500.0     3.725
# 2   2018  148893666.666667        6315250.0  7109166.666667      3.85
# 3   2019  150905083.333333   5999166.666667  7153833.333333  3.866667
# 4   2020  142161916.666667  12949666.666667  6349333.333333  4.258333
# 5   2021  146284333.333333   8629916.666667  9979416.666667  4.341667
# 6   2022  152549166.666667   5992666.666667      11194750.0       4.2
# 7   2023       155895250.0   6076833.333333       9268000.0  3.758333
# 8   2024  157693833.333333   6762166.666667  7656666.666667  3.416667
# 9   2025  158438916.666667   7281727.272727  7081666.666667  3.316667
# 10  2026  158731166.666667   7266857.142857       7245600.0      3.32
#
# 0  Layoffs_Avg
# 0        1.225
# 1        1.225
# 2     1.216667
# 3     1.208333
# 4          2.4
# 5     0.966667
# 6     0.958333
# 7     1.066667
# 8     1.058333
# 9     1.116667
# 10        1.08

# %%
#analyzing the data
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#this starts a new plot and set the size of it
plt.figure(figsize=(16,6))

# %%
sns.lineplot(data=merged, x="Year", y="Employees_Avg", label= "Employees")# I want to show a line graph showing how it has evolved during the years
plt.title("Number of Employees in the U.S") #Title
plt.xlabel("Year") #label for the x axis
plt.ylabel("Average")#label for y axis
plt.grid(True)#shows a grid behind the plot
plt.show()

# %%
sns.lineplot(data=merged, x="Year", y="Unemployees_Avg", label= "Unemployees")# I want to show a line graph showing how it has evolved during the years
plt.show()

# %%
#created a heatmap to show the correlation between variables
corr = merged.corr() 
plt.figure(figsize=(10,6))#size of the heatmap
sns.heatmap(corr, annot = True, cmap="coolwarm", fmt=".2f")#heatmap structure and showed by temperature
plt.title("Correlation map")
plt.show()
